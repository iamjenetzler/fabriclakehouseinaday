# %%
# Set medallion paths
bronzePath = f"abfss://classroomB2@msit-onelake.dfs.fabric.microsoft.com/liad_bronze.Lakehouse/Files"
# silverPath = f"Tables/silver"
# goldPath = f"Tables/gold"

#files = mssparkutils.fs.ls(f"abfss://classroomB2@msit-onelake.dfs.fabric.microsoft.com/liad_gold.Lakehouse/Tables/flightdata")
bronzeLakehouse = f"liad_bronze"
silverLakehouse = f"liad_silver"
goldLakehouse = f"liad_gold"
# Out:
# StatementMeta(, ee9cd631-538d-486a-9e4c-ecbba2c30dbc, 5, Finished, Available)

# %%
# Return to the caller, passing the variables needed for file paths and database

# response = bronzePath + " " + silverPath + " " + goldPath + " " + bronzeLakehouse + " " + silverLakehouse + " " + goldLakehouse + " "
response = bronzePath + " " + bronzeLakehouse + " " + silverLakehouse + " " + goldLakehouse + " "

mssparkutils.notebook.exit(response)
# Out:
# StatementMeta(, ee9cd631-538d-486a-9e4c-ecbba2c30dbc, 6, Finished, Available)
# ExitValue: abfss://classroomB2@msit-onelake.dfs.fabric.microsoft.com/liad_bronze.Lakehouse/Files liad_bronze liad_silver liad_gold
